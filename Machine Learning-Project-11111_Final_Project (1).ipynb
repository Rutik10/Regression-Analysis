# %% [markdown]
#                         CS677 – Introduction to Machine Learning
#                                        Project 1

# %% [markdown]
#                         Group Member's Name: Rutik Kothwala
#                                              Malav Shah
#                                              Chandani Thumar

# %%
# Importing the California housing data from sklearn dataset
from sklearn.datasets import fetch_california_housing

# %%
import pandas as pd

# %%
data = fetch_california_housing(as_frame=True)

# %%
data.frame.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
data.frame.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
data=data.frame

# %% [markdown]
# ## Data inspections

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
data.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %% [markdown]
# Here we can se that there are no missing value in our given data Now we will look for outlier

# %% [markdown]
# ## Outliers

# %%
# Using pandas describe() to find outliers
data.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %% [markdown]
# So from above it can be observed that there are outliers in the above data has min and max value differ greatly from the mean value

# %% [markdown]
#  Ploting Box plot to look for outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# MedInc

# %%
sns.boxplot (y=data['MedInc'])
# Out:
# <AxesSubplot:ylabel='MedInc'>

# %% [markdown]
#                  Outliers are observed in MedInc

# %%
data=data[data['MedInc']<=8]

# %%
sns.boxplot (y=data['MedInc'])
# Out:
# <AxesSubplot:ylabel='MedInc'>

# %% [markdown]
#                    Removed outliers in MedInc

# %% [markdown]
# HouseAge

# %%
sns.boxplot (y=data['HouseAge'])
# Out:
# <AxesSubplot:ylabel='HouseAge'>

# %% [markdown]
#               No outliers are observed in HouseAge

# %% [markdown]
# AveRooms

# %%
sns.boxplot (y=data['AveRooms'])
# Out:
# <AxesSubplot:ylabel='AveRooms'>

# %% [markdown]
#                     Outliers are observed in AveRooms

# %%
data=data[data['AveRooms']<=10]

# %%
sns.boxplot (y=data['AveRooms'])
# Out:
# <AxesSubplot:ylabel='AveRooms'>

# %%
data=data[data['AveRooms']<=8]

# %%
data=data[data['AveRooms']>=2]

# %%
sns.boxplot (y=data['AveRooms'])
# Out:
# <AxesSubplot:ylabel='AveRooms'>

# %% [markdown]
#                   Removed outliers from AveRooms

# %% [markdown]
# AveBedrms

# %%
sns.boxplot (y=data['AveBedrms'])
# Out:
# <AxesSubplot:ylabel='AveBedrms'>

# %% [markdown]
#                   Outliers are observed in Avebedrms

# %%
data=data[data['AveBedrms']<=1.3]

# %%
sns.boxplot (y=data['AveBedrms'])
# Out:
# <AxesSubplot:ylabel='AveBedrms'>

# %%
data=data[data['AveBedrms']<=1.2]
data=data[data['AveBedrms']>=0.9]

# %%
sns.boxplot (y=data['AveBedrms'])
# Out:
# <AxesSubplot:ylabel='AveBedrms'>

# %% [markdown]
#                         Removed outliers in AveBedrms

# %% [markdown]
# Population

# %%
sns.boxplot (y=data['Population'])
# Out:
# <AxesSubplot:ylabel='Population'>

# %% [markdown]
#                     Outliers are observed in Population

# %%
data=data[data['Population']<=5000]

# %%
sns.boxplot (y=data['Population'])
# Out:
# <AxesSubplot:ylabel='Population'>

# %%
data=data[data['Population']<=3000]

# %%
sns.boxplot (y=data['Population'])
# Out:
# <AxesSubplot:ylabel='Population'>

# %% [markdown]
#                       Removed outliers from Population

# %% [markdown]
# AveOccup

# %%
sns.boxplot (y=data['AveOccup'])
# Out:
# <AxesSubplot:ylabel='AveOccup'>

# %% [markdown]
#                     Outliers are observed in AveOccup

# %%
data=data[data['AveOccup']<=100]

# %%
sns.boxplot (y=data['AveOccup'])
# Out:
# <AxesSubplot:ylabel='AveOccup'>

# %%
data=data[data['AveOccup']<=10]

# %%
sns.boxplot (y=data['AveOccup'])
# Out:
# <AxesSubplot:ylabel='AveOccup'>

# %%
data=data[data['AveOccup']<=5]

# %%
sns.boxplot (y=data['AveOccup'])
# Out:
# <AxesSubplot:ylabel='AveOccup'>

# %%
data=data[data['AveOccup']<=4.5]
data=data[data['AveOccup']>=1.3]

# %%
sns.boxplot (y=data['AveOccup'])
# Out:
# <AxesSubplot:ylabel='AveOccup'>

# %% [markdown]
#                      Removed outliers from AveOccup

# %% [markdown]
# Latitude

# %%
sns.boxplot (y=data['Latitude'])
# Out:
# <AxesSubplot:ylabel='Latitude'>

# %% [markdown]
#                     No outliers are observed in Latitude

# %% [markdown]
# Longitude

# %%
sns.boxplot (y=data['Longitude'])
# Out:
# <AxesSubplot:ylabel='Longitude'>

# %% [markdown]
#                  No ooutliers are observed in Longitude

# %% [markdown]
# MedHouseVal

# %%
sns.boxplot (y=data['MedHouseVal'])
# Out:
# <AxesSubplot:ylabel='MedHouseVal'>

# %% [markdown]
#                   Outliers are observed in MedhouseVal

# %%
data=data[data['MedHouseVal']<=4]

# %%
sns.boxplot (y=data['MedHouseVal'])
# Out:
# <AxesSubplot:ylabel='MedHouseVal'>

# %% [markdown]
#                    Removed outliers from MedHouseVal

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15064 entries, 3 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       15064 non-null  float64
#  1   HouseAge     15064 non-null  float64
#  2   AveRooms     15064 non-null  float64
#  3   AveBedrms    15064 non-null  float64
#  4   Population   15064 non-null  float64
#  5   AveOccup     15064 non-null  float64
#  6   Latitude     15064 non-null  float64
#  7   Longitude    15064 non-null  float64
#  8   MedHouseVal  15064 non-null  float64
# dtypes: float64(9)
# memory usage: 1.1 MB

# %% [markdown]
# #### Data entries are now 15064 after removing outliers

# %%
data.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  15064.000000  15064.000000  15064.000000  15064.000000  15064.000000
# mean       3.605874     29.386949      5.134736      1.045403   1267.988980
# std        1.393837     12.127921      1.016159      0.061162    606.259849
# min        0.536000      1.000000      2.000000      0.900000      5.000000
# 25%        2.550550     19.000000      4.426487      1.002888    823.000000
# 50%        3.454250     30.000000      5.129347      1.042684   1165.000000
# 75%        4.506600     37.000000      5.817047      1.086327   1632.000000
# max        7.997700     52.000000      7.995495      1.200000   2999.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  15064.000000  15064.000000  15064.000000  15064.000000
# mean       2.874165     35.686212   -119.625797      1.850571
# std        0.615640      2.149302      1.991941      0.844712
# ...

# %% [markdown]
#        Here the range of the different features are different so normalization is required

# %% [markdown]
# #### Feature selection

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
normalized_data = scaler.fit_transform(data)

# %%
import pandas as pd

# %%
data = pd.DataFrame(normalized_data, columns=data.columns)

# %%
data.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  15064.000000  15064.000000  15064.000000  15064.000000  15064.000000
# mean       0.411417      0.556607      0.522848      0.484677      0.421840
# std        0.186799      0.237802      0.169487      0.203872      0.202492
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.269985      0.352941      0.404718      0.342960      0.273213
# 50%        0.391097      0.568627      0.521950      0.475614      0.387442
# 75%        0.532131      0.705882      0.636652      0.621091      0.543420
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  15064.000000  15064.000000  15064.000000  15064.000000
# mean       0.491795      0.334348      0.483047      0.441708
# std        0.192437      0.228406      0.203675      0.219405
# ...

# %%
corr_matrix = data.corr()

# %%
corr_matrix
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.194680  0.695268  -0.257508    0.001447 -0.016481
# HouseAge    -0.194680  1.000000 -0.209471  -0.061360   -0.263858  0.007362
# AveRooms     0.695268 -0.209471  1.000000  -0.017712   -0.069699  0.060287
# AveBedrms   -0.257508 -0.061360 -0.017712   1.000000    0.082765 -0.086783
# Population   0.001447 -0.263858 -0.069699   0.082765    1.000000  0.208336
# AveOccup    -0.016481  0.007362  0.060287  -0.086783    0.208336  1.000000
# Latitude    -0.087190  0.001454  0.133485   0.042294   -0.113994 -0.173056
# Longitude    0.004203 -0.085339 -0.089055  -0.014606    0.105628  0.188838
# MedHouseVal  0.627281  0.066875  0.245908  -0.100580    0.006714 -0.249925
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.087190   0.004203     0.627281
# HouseAge     0.001454  -0.085339     0.066875
# AveRooms     0.133485  -0.089055     0.245908
# ...

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', square=True, linewidths=.5, ax=ax)
plt.title('Correlation Heatmap')
plt.show()

# %%
data.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  15064.000000  15064.000000  15064.000000  15064.000000  15064.000000
# mean       0.411417      0.556607      0.522848      0.484677      0.421840
# std        0.186799      0.237802      0.169487      0.203872      0.202492
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.269985      0.352941      0.404718      0.342960      0.273213
# 50%        0.391097      0.568627      0.521950      0.475614      0.387442
# 75%        0.532131      0.705882      0.636652      0.621091      0.543420
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  15064.000000  15064.000000  15064.000000  15064.000000
# mean       0.491795      0.334348      0.483047      0.441708
# std        0.192437      0.228406      0.203675      0.219405
# ...

# %% [markdown]
# ## ML Linear Regressor Models:

# %% [markdown]
# ### 1. Ordinary Least Squares(OLS)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# split the dataset into training and testing setsX_train, X_test, y_train, y_test = train_test_split(data_new.drop('MedHouseVal', axis=1), data_new['MedHouseVal'], test_size=0.2, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(data.drop('MedHouseVal', axis=1), data['MedHouseVal'], test_size=0.2, random_state=42)
# create an instance of the linear regression model
model = LinearRegression()

# fit the model on the training data
model.fit(X_train, y_train)

# predict on the testing data
y_pred = model.predict(X_test)

# print the model's coefficients and intercept
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)

mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error (MSE):', mse)

# calculate the Root Mean Squared Error (RMSE)
rmse = mean_squared_error(y_test, y_pred, squared=False)
print('Root Mean Squared Error (RMSE):', rmse)

# calculate the R-squared
r2_ols_1 = r2_score(y_test, y_pred)
print('R-squared:', r2_ols_1)

plt.scatter(y_test, y_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()
# Out:
# Coefficients: [ 0.80602122  0.1087081  -0.17752758  0.08986058  0.06056779 -0.26671896
#  -0.92989177 -0.96754102]
# Intercept: 0.9826182901244546
# Mean Squared Error (MSE): 0.017405279670355257
# Root Mean Squared Error (RMSE): 0.13192907060369696
# R-squared: 0.6305814567968933

# %% [markdown]
# ### 2. LASSO Regressor(L1)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
import matplotlib.pyplot as plt

X = data[['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup','Latitude','Longitude','Population']]
Y = data['MedHouseVal']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

lasso = Lasso()
lasso.fit(X_train, Y_train)

Y_pred = lasso.predict(X_test)

mse = mean_squared_error(Y_test, Y_pred)
r2_lasso_1 = r2_score(Y_test, Y_pred)

print("MSE:", mse)
print("R^2:", r2_lasso_1)

plt.scatter(Y_test, Y_pred)
plt.xlabel("True values")
plt.ylabel("Predicted values")
plt.title("Lasso Regression")
plt.show()
# Out:
# MSE: 0.047141457286665966
# R^2: -0.0005543608111509002

# %% [markdown]
# ### 3. Ridge Regressor(L2)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
import matplotlib.pyplot as plt

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

ridge = Ridge()
ridge.fit(X_train, Y_train)

Y_pred = ridge.predict(X_test)

mse = mean_squared_error(Y_test, Y_pred)
r2_ridge_1 = r2_score(Y_test, Y_pred)

print("MSE:", mse)
print("R^2:", r2_ridge_1)

plt.scatter(Y_test, Y_pred)
plt.xlabel("True values")
plt.ylabel("Predicted values")
plt.title("Ridge Regression")
plt.show()
# Out:
# MSE: 0.017399768754022663
# R^2: 0.630698423299119

# %% [markdown]
# ### 4.  Elastic Regressor(L1 & L2)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import GridSearchCV

elastic = ElasticNet()

# %%
import warnings;warnings.simplefilter('ignore')

# %%
elastic.fit(X,Y)
# Out:
# ElasticNet()

# %%
Y_pred = elastic.predict(X_test)

mse = mean_squared_error(Y_test, Y_pred)
r2_elastic_1 = r2_score(Y_test, Y_pred)
print("MSE:", mse)
print("R^2:", r2_elastic_1)

plt.scatter(Y_test, Y_pred)
plt.xlabel("True values")
plt.ylabel("Predicted values")
plt.title("ElasticNet Regressor")
plt.show()
# Out:
# MSE: 0.04713205392884014
# R^2: -0.0003547791431151026

# %%
print("The r-squared on the training data is",elastic.score(X_train,Y_train)*100)

print("The r-squared on the testing data is",elastic.score(X_test,Y_test)*100)
# Out:
# The r-squared on the training data is -0.002159532264367492
# The r-squared on the testing data is -0.03547791431151026

# %% [markdown]
#                 Final comparision chart before Hyperparameter Tuning

# %%
import matplotlib.pyplot as plt

# define data
values = [r2_ols_1, r2_lasso_1, r2_ridge_1, r2_elastic_1]
x_labels = ['OLS', 'Lasso', 'Ridge', 'Elastic']

# plot bars
plt.bar(x_labels, values, color=['red', 'green', 'blue', 'orange'], edgecolor='white')

# add x-axis labels and title
plt.xlabel('Model')
plt.ylabel('R2')
plt.title('Comparision of R-squared values pre Hyperparameter Tuning')

# display graph
plt.show()

# %% [markdown]
# ## Hyperperameter Tunning

# %% [markdown]
# ### 1. Elastic Regressor(L1 & L2)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import GridSearchCV

# %%
import warnings;warnings.simplefilter('ignore')

# %%
# Plotting the prediction error and residuals using yellowbrick module
from sklearn.preprocessing import StandardScaler

# %%
from yellowbrick.regressor import PredictionError

# %%
r_train, r_test, s_train, s_test = train_test_split(data.drop('MedHouseVal', axis=1), data['MedHouseVal'], test_size=0.2, random_state=42)

# %%
# scale the data
scaler = StandardScaler()
r_train_scaled = scaler.fit_transform(r_train)
r_test_scaled = scaler.transform(r_test)

# %%
# create Elastic regression model
elastic_reg = ElasticNet(random_state=42)

# %%
# define hyperparameters to tune using grid search
params = {
    'alpha': [0.1, 1, 10],
    'l1_ratio': [0.2, 0.5, 0.8]
}

# %%
# perform grid search with cross-validation to find best hyperparameters
grid_search = GridSearchCV(elastic_reg, params, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(r_train_scaled, s_train)
# Out:
# GridSearchCV(cv=5, estimator=ElasticNet(random_state=42),
#              param_grid={'alpha': [0.1, 1, 10], 'l1_ratio': [0.2, 0.5, 0.8]},
#              scoring='neg_mean_squared_error')

# %%
# print best hyperparameters and their score
print("Best hyperparameters: ", grid_search.best_params_)
print("Best score: {:.2f}".format(grid_search.best_score_))
# Out:
# Best hyperparameters:  {'alpha': 0.1, 'l1_ratio': 0.2}
# Best score: -0.03

# %%
# predict on test set using best model
best_model = grid_search.best_estimator_
s_pred = best_model.predict(r_test_scaled)

# %%
# evaluate performance using mean squared error
mse = mean_squared_error(s_test, s_pred)
print("Mean Squared Error: {:.2f}".format(mse))
# Out:
# Mean Squared Error: 0.03

# %%
r2 = r2_score(s_test, s_pred)
print("R^2:", r2)
# Out:
# R^2: 0.46284378769760304

# %%
plt.scatter(s_test, s_pred)
plt.xlabel("True values")
plt.ylabel("Predicted values")
plt.title("ElasticNet Regressor")
plt.show()

# %%
# Plotting the prediction error and residuals using yellowbrick module
from sklearn.preprocessing import StandardScaler

# %%
pip install yellowbrick
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from yellowbrick.regressor import PredictionError

# %%
visualizer = PredictionError(best_model)
visualizer.fit(r_train,s_train)
visualizer.score(r_test_scaled,s_test)
visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Prediction Error for ElasticNet'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
from yellowbrick.regressor import ResidualsPlot

# %%
visualizer = ResidualsPlot(best_model)
visualizer.fit(r_train_scaled,s_train)
visualizer.score(r_test_scaled,s_test)
visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Residuals for ElasticNet Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
import matplotlib.pyplot as plt

# define data
values = [r2_elastic_1, r2]
x_labels = ['Pre', 'Post']

# plot bars
plt.bar(x_labels, values, color=['red', 'green'], edgecolor='white')

# add x-axis labels and title
plt.xlabel('Hypertuning of Elastic')
plt.ylabel('R2')
plt.title('Comparision of R2 values post Hypertuning')

# display graph
plt.show()

# %% [markdown]
# ### 2. Ordinary Least Squares(OLS)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Create the X and y matrices
X  = data[['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup','Latitude','Longitude','Population']] # independent variables
y = data['MedHouseVal'] # dependent variable

# %%
# Check for multicollinearity using the variance inflation factor (VIF)
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
print(vif)
# Out:
#    VIF Factor    features
# 0   13.351466      MedInc
# 1    6.063163    HouseAge
# 2   26.855138    AveRooms
# 3    7.256105   AveBedrms
# 4    8.408331    AveOccup
# 5    7.561809    Latitude
# 6   14.300943   Longitude
# 7    6.022934  Population

# %%
# Create the X and y matrices
X  = data[['MedInc', 'HouseAge', 'AveBedrms', 'AveOccup','Latitude','Longitude','Population']] # independent variables
y = data['MedHouseVal'] # dependent variable

# %%
# Check for multicollinearity using the variance inflation factor (VIF)
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
print(vif)
# Out:
#    VIF Factor    features
# 0    5.365057      MedInc
# 1    5.915985    HouseAge
# 2    6.898768   AveBedrms
# 3    8.179699    AveOccup
# 4    5.916514    Latitude
# 5   12.851306   Longitude
# 6    5.786150  Population

# %%
# Create the X and y matrices
X  = data[['MedInc', 'HouseAge', 'AveBedrms', 'AveOccup','Latitude','Population']] # independent variables
y = data['MedHouseVal'] # dependent variable

# %%
# Check for multicollinearity using the variance inflation factor (VIF)
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
print(vif)
# Out:
#    VIF Factor    features
# 0    4.345912      MedInc
# 1    4.994965    HouseAge
# 2    5.356198   AveBedrms
# 3    6.852209    AveOccup
# 4    2.870418    Latitude
# 5    5.355474  Population

# %%
data_new2  = data[['MedInc', 'HouseAge', 'AveBedrms', 'AveOccup','Latitude','Population','MedHouseVal']]

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(data_new2.drop('MedHouseVal', axis=1), data_new2['MedHouseVal'], test_size=0.2, random_state=42)

# %%
# fit the model on the training data
model.fit(X2_train, y2_train)

# predict on the testing data
y2_pred = model.predict(X2_test)

# %%
# print the model's coefficients and intercept
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)

mse = mean_squared_error(y2_test, y2_pred)
print('Mean Squared Error (MSE):', mse)

# calculate the Root Mean Squared Error (RMSE)
rmse = mean_squared_error(y2_test, y2_pred, squared=False)
print('Root Mean Squared Error (RMSE):', rmse)

# calculate the R-squared
r2 = r2_score(y2_test, y2_pred)
print('R-squared:', r2)
# Out:
# Coefficients: [ 0.79550969  0.21766455  0.06852473 -0.32457115 -0.1432627   0.11673533]
# Intercept: 0.11840576096779187
# Mean Squared Error (MSE): 0.022752223938134697
# Root Mean Squared Error (RMSE): 0.1508384033929513
# R-squared: 0.5170951814022178

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %%
lr = LinearRegression()
lr.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
X_test_scaled = scaler.transform(X_test)
y_pred_train = lr.predict(X_train_scaled)
y_pred_test = lr.predict(X_test_scaled)

r2_train = r2_score(y_train, y_pred_train)
r2_test = r2_score(y_test, y_pred_test)

print('Training R2 Score:', r2_train)
print('Testing R2 Score:', r2_test)
# Out:
# Training R2 Score: 0.6436665099423289
# Testing R2 Score: 0.6305814567968933

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(lr, X_train_scaled, y_train, cv=5)
print('Cross Validation Scores:', cv_scores)
print('Mean CV Score:', np.mean(cv_scores))
# Out:
# Cross Validation Scores: [0.65563791 0.63172844 0.63204861 0.64448646 0.64916394]
# Mean CV Score: 0.6426130715937228

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'copy_X': [True, False]
}
grid_search = GridSearchCV(lr, param_grid=param_grid, cv=5)
grid_search.fit(X_train_scaled, y_train)

print('Best Parameters:', grid_search.best_params_)
# Out:
# Best Parameters: {'copy_X': True, 'fit_intercept': True, 'normalize': True}

# %%
lr_best = LinearRegression(**grid_search.best_params_)
lr_best.fit(X_train_scaled, y_train)

X_test_scaled = scaler.transform(X_test)
y_pred_train_best = lr_best.predict(X_train_scaled)
y_pred_test_best = lr_best.predict(X_test_scaled)

r2_train_best = r2_score(y_train, y_pred_train_best)
r2_test_best_linear = r2_score(y_test, y_pred_test_best)

print('Training R2 Score (Best Parameters):', r2_train_best)
print('Testing R2 Score (Best Parameters):', r2_test_best_linear)
# Out:
# Training R2 Score (Best Parameters): 0.6436665099423289
# Testing R2 Score (Best Parameters): 0.6305814567968933

# %%
# Generate a prediction error plot using Yellowbrick
viz = PredictionError(lr_best)
viz.fit(X_train_scaled, y_train)
viz.score(X_test_scaled, y_test)
viz.show()
# Out:
# <AxesSubplot:title={'center':'Prediction Error for LinearRegression'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
visualizer =ResidualsPlot(lr_best)
visualizer.fit(X_train_scaled,y_train)
visualizer.score(X_test_scaled,y_test)
visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
import matplotlib.pyplot as plt

# define data
values = [r2_ols_1, r2_test_best_linear]
x_labels = ['Pre', 'Post']

# plot bars
plt.bar(x_labels, values, color=['red', 'green'], edgecolor='white')

# add x-axis labels and title
plt.xlabel('Hypertuning of OLS')
plt.ylabel('R2')
plt.title('Comparision of R2 values post Hypertuning')

# display graph
plt.show()

# %% [markdown]
# ### 3. LASSO Regressor(L1)

# %%
lasso = Lasso()
lasso.fit(X_train_scaled, y_train)
# Out:
# Lasso()

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(lasso, X_train_scaled, y_train, cv=5)
print('Cross Validation Scores:', cv_scores)
print('Mean CV Score:', np.mean(cv_scores))
# Out:
# Cross Validation Scores: [-2.64914544e-03 -1.05433932e-04 -4.26886658e-04 -1.03367252e-03
#  -9.01952404e-05]
# Mean CV Score: -0.0008610667596304466

# %%
# Use Cross Validation Method to Tune The Model

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'alpha': [0.001, 0.01, 0.1, 1, 10],
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'selection': ['cyclic', 'random']
}

grid_search = GridSearchCV(lasso, param_grid=param_grid, cv=5)
grid_search.fit(X_train_scaled, y_train)

print('Best Parameters:', grid_search.best_params_)
# Out:
# Best Parameters: {'alpha': 0.001, 'fit_intercept': True, 'normalize': False, 'selection': 'cyclic'}

# %%
lasso_best = Lasso(**grid_search.best_params_)
lasso_best.fit(X_train_scaled, y_train)

X_test_scaled = scaler.transform(X_test)
y_pred_train_best = lasso_best.predict(X_train_scaled)
y_pred_test_best = lasso_best.predict(X_test_scaled)

r2_train_best = r2_score(y_train, y_pred_train_best)
r2_test_best_lasso = r2_score(y_test, y_pred_test_best)

print('Training R2 Score (Best Parameters):', r2_train_best)
print('Testing R2 Score (Best Parameters):', r2_test_best_lasso)
# Out:
# Training R2 Score (Best Parameters): 0.6429731593033501
# Testing R2 Score (Best Parameters): 0.6307646885101181

# %%
viz = PredictionError(lasso_best)
viz.fit(X_train_scaled, y_train)
viz.score(X_test_scaled, y_test)
viz.show()
# Out:
# <AxesSubplot:title={'center':'Prediction Error for Lasso'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
visualizer =ResidualsPlot(lasso_best)
visualizer.fit(X_train_scaled,y_train)
visualizer.score(X_test_scaled,y_test)
visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Residuals for Lasso Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
import matplotlib.pyplot as plt

# define data
values = [r2_lasso_1, r2_test_best_lasso]
x_labels = ['Pre', 'Post']

# plot bars
plt.bar(x_labels, values, color=['red', 'green'], edgecolor='white')

# add x-axis labels and title
plt.xlabel('Hypertuning of Lasso')
plt.ylabel('R2')
plt.title('Comparision of R2 values post Hypertuning')

# display graph
plt.show()

# %% [markdown]
# ### 4. Ridge Regressor(L2)

# %%
ridge = Ridge(alpha=1.0)
ridge.fit(X_train_scaled, y_train)
# Out:
# Ridge()

# %%
X_test_scaled = scaler.transform(X_test)
y_pred_train = ridge.predict(X_train_scaled)
y_pred_test = ridge.predict(X_test_scaled)

r2_train = r2_score(y_train, y_pred_train)
r2_test = r2_score(y_test, y_pred_test)

print('Training R2 Score:', r2_train)
print('Testing R2 Score:', r2_test)
# Out:
# Training R2 Score: 0.6436663031256151
# Testing R2 Score: 0.6305894311238889

# %%
cv_scores = cross_val_score(ridge, X_train_scaled, y_train, cv=5)
print('Cross Validation Scores:', cv_scores)
print('Mean CV Score:', np.mean(cv_scores))
# Out:
# Cross Validation Scores: [0.65562546 0.63171412 0.63206671 0.6445093  0.64915126]
# Mean CV Score: 0.6426133687019877

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'alpha': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0],
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'copy_X': [True, False]
}

grid_search = GridSearchCV(ridge, param_grid=param_grid, cv=5)
grid_search.fit(X_train_scaled, y_train)

print('Best Parameters:', grid_search.best_params_)
# Out:
# Best Parameters: {'alpha': 1.0, 'copy_X': True, 'fit_intercept': True, 'normalize': False}

# %%
ridge_best = Ridge(**grid_search.best_params_)
ridge_best.fit(X_train_scaled, y_train)

X_test_scaled = scaler.transform(X_test)
y_pred_train_best = ridge_best.predict(X_train_scaled)
y_pred_test_best = ridge_best.predict(X_test_scaled)

r2_train_best = r2_score(y_train, y_pred_train_best)
r2_test_best_ridge = r2_score(y_test, y_pred_test_best)

print('Training R2 Score (Best Parameters):', r2_train_best)
print('Testing R2 Score (Best Parameters):', r2_test_best_ridge)
# Out:
# Training R2 Score (Best Parameters): 0.6436663031256151
# Testing R2 Score (Best Parameters): 0.6305894311238889

# %%
viz = PredictionError(ridge_best)
viz.fit(X_train_scaled, y_train)
viz.score(X_test_scaled, y_test)
viz.show()
# Out:
# <AxesSubplot:title={'center':'Prediction Error for Ridge'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
visualizer =ResidualsPlot(ridge_best)
visualizer.fit(X_train_scaled,y_train)
visualizer.score(X_test_scaled,y_test)
visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Residuals for Ridge Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
import matplotlib.pyplot as plt

# define data
values = [r2_ridge_1, r2_test_best_ridge]
x_labels = ['Pre', 'Post']

# plot bars
plt.bar(x_labels, values, color=['red', 'green'], edgecolor='white')

# add x-axis labels and title
plt.xlabel('Hypertuning of Ridge')
plt.ylabel('R2')
plt.title('Comparision of R2 values post Hypertuning')

# display graph
plt.show()

# %% [markdown]
#                Final comparision chart after Hyperparameter Tuning

# %%
import matplotlib.pyplot as plt

# define data
values = [r2, r2_test_best_lasso, r2_test_best_ridge, r2_test_best_linear]
x_labels = ['Elastic', 'Lasso', 'Ridge', 'OLS']

# plot bars
plt.bar(x_labels, values, color=['red', 'green', 'blue', 'orange'], edgecolor='white')

# add x-axis labels and title
plt.xlabel('Model')
plt.ylabel('R2')
plt.title('Comparision of R2 values post Hyperparameter Tuning')

# display graph
plt.show()

# %% [markdown]
# ### Conclusion

# %% [markdown]
# It is observed that:-
#
# Ordinary Least Sqaures (OLS) and Ridge Regressor perform well even without tunning result is almost similar with or without tunning.
#
# But LASSO Regressor (L1) and Elastic Regressor (L1 & L2) not performed as good as above model without tunning, and in it great change is observed and result are quite good after tunning especially in r2 value (R Sqaure value).
#
# Below result table give information about MSE and r2 value for all the model with and without tunning

# %% [markdown]
# #### Before Hyperparameter Tunning  Chart

# %% [markdown]
# ![Screen%20Shot%202023-03-01%20at%206.15.36%20PM.png](attachment:Screen%20Shot%202023-03-01%20at%206.15.36%20PM.png)

# %% [markdown]
# #### After Hyperparameter Tunnning Chart

# %% [markdown]
# ![Screen%20Shot%202023-03-01%20at%206.17.33%20PM.png](attachment:Screen%20Shot%202023-03-01%20at%206.17.33%20PM.png)
